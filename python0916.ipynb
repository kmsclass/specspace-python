# %%
import pandas as pd
exam_data = {'이름' : [ '서준', '우현', '인아'],
             '수학' : [ 90, 80, 70],
             '영어' : [ 98, 89, 95],
             '음악' : [ 85, 95, 100],
             '체육' : [ 100, 90, 90]}
df = pd.DataFrame(exam_data)
df
# Out:
#    이름  수학  영어   음악   체육
# 0  서준  90  98   85  100
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90

# %%
# 국어 컬럼 추가하기 : 80,90,95 
df["국어"]=[80,90,95]
df
# Out:
#    이름  수학  영어   음악   체육  국어
# 0  서준  90  98   85  100  80
# 1  우현  80  89   95   90  90
# 2  인아  70  95  100   90  95

# %%
#행 추가하기
df.loc[3]=['길동',75,80,90,95,85]
df
# Out:
#    이름  수학  영어   음악   체육  국어
# 0  서준  90  98   85  100  80
# 1  우현  80  89   95   90  90
# 2  인아  70  95  100   90  95
# 3  길동  75  80   90   95  85

# %%
df.loc[5]=['길순',75,80,90,95,85]
df
# Out:
#    이름  수학  영어   음악   체육  국어
# 0  서준  90  98   85  100  80
# 1  우현  80  89   95   90  90
# 2  인아  70  95  100   90  95
# 3  길동  75  80   90   95  85
# 5  길순  75  80   90   95  85

# %%
df.loc[4] = df.loc[2]
df
# Out:
#    이름  수학  영어   음악   체육  국어
# 0  서준  90  98   85  100  80
# 1  우현  80  89   95   90  90
# 2  인아  70  95  100   90  95
# 3  길동  75  80   90   95  85
# 5  길순  75  80   90   95  85
# 4  인아  70  95  100   90  95

# %%
#길순이의 데이터 제거하기
df.drop(5,inplace=True, axis=0)
df
# Out:
#    이름  수학  영어   음악   체육  국어
# 0  서준  90  98   85  100  80
# 1  우현  80  89   95   90  90
# 2  인아  70  95  100   90  95
# 3  길동  75  80   90   95  85
# 4  인아  70  95  100   90  95

# %%
#4번의 이름을 길순변경하기
df.loc[4,'이름']='길순'
df
# Out:
#    이름  수학  영어   음악   체육  국어
# 0  서준  90  98   85  100  80
# 1  우현  80  89   95   90  90
# 2  인아  70  95  100   90  95
# 3  길동  75  80   90   95  85
# 4  길순  70  95  100   90  95

# %%
#set_index : 이름 컬럼을 인덱스 설정하기
df.set_index("이름",inplace=True)
df
# Out:
#     수학  영어   음악   체육  국어
# 이름
# 서준  90  98   85  100  80
# 우현  80  89   95   90  90
# 인아  70  95  100   90  95
# 길동  75  80   90   95  85
# 길순  70  95  100   90  95

# %%
df.index
# Out:
# Index(['서준', '우현', '인아', '길동', '길순'], dtype='str', name='이름')

# %%
#서준이의 체육점수 80점으로 변경하기
df.loc["서준","체육"]=80
df
# Out:
#     수학  영어   음악  체육  국어
# 이름
# 서준  90  98   85  80  80
# 우현  80  89   95  90  90
# 인아  70  95  100  90  95
# 길동  75  80   90  95  85
# 길순  70  95  100  90  95

# %%
df.iloc[0,3]=80
df
# Out:
#     수학  영어   음악  체육  국어
# 이름
# 서준  90  98   85  80  80
# 우현  80  89   95  90  90
# 인아  70  95  100  90  95
# 길동  75  80   90  95  85
# 길순  70  95  100  90  95

# %%
#우현이의 음악.체육 점수를 100,70 변경하기
df.loc["우현",["음악","체육"]] = 100,70
df
# Out:
#     수학  영어   음악  체육  국어
# 이름
# 서준  90  98   85  80  80
# 우현  80  89  100  70  90
# 인아  70  95  100  90  95
# 길동  75  80   90  95  85
# 길순  70  95  100  90  95

# %%
#범위 지정하여 출력하기
# 우현에서 길동까지 조회하기
df.loc["우현":"길동"]
df.iloc[1:4]
# Out:
#     수학  영어   음악  체육  국어
# 이름
# 우현  80  89  100  70  90
# 인아  70  95  100  90  95
# 길동  75  80   90  95  85

# %%
# 우현이부터 길동까지 수학점수만 출력하기
df.loc["우현":"길동","수학"]
# Out:
# 이름
# 우현    80
# 인아    70
# 길동    75
# Name: 수학, dtype: int64

# %%
# 우현이부터 길동까지 수학점수에서 음악점수까지 출력하기
df.loc["우현":"길동","수학":"음악"]
# Out:
#     수학  영어   음악
# 이름
# 우현  80  89  100
# 인아  70  95  100
# 길동  75  80   90

# %%
# 우현이부터 길동까지 수학점수 와 음악점수 출력하기
df.loc["우현":"길동",["수학","음악"]]
# Out:
#     수학   음악
# 이름
# 우현  80  100
# 인아  70  100
# 길동  75   90

# %%
# 우현와 길동이의 수학점수 와 음악점수 출력하기
df.loc[["우현","길동"],["수학","음악"]]
# Out:
#     수학   음악
# 이름
# 우현  80  100
# 길동  75   90

# %%
df
# Out:
#     수학  영어   음악  체육  국어
# 이름
# 서준  90  98   85  80  80
# 우현  80  89  100  70  90
# 인아  70  95  100  90  95
# 길동  75  80   90  95  85
# 길순  70  95  100  90  95

# %%
#서준, 인아, 길순 조회하기
#df[::2]
#df.loc[::2]
df.iloc[::2]
# Out:
#     수학  영어   음악  체육  국어
# 이름
# 서준  90  98   85  80  80
# 인아  70  95  100  90  95
# 길순  70  95  100  90  95

# %%
#역순으로 출력하기
#df[::-1]
#df.loc[::-1]
df.iloc[::-1]
# Out:
#     수학  영어   음악  체육  국어
# 이름
# 길순  70  95  100  90  95
# 길동  75  80   90  95  85
# 인아  70  95  100  90  95
# 우현  80  89  100  70  90
# 서준  90  98   85  80  80

# %%
#역순으로 한칸 건너씩 출력하기
df[::-2]
#df.loc[::-2]
#df.iloc[::-2]
# Out:
#     수학  영어   음악  체육  국어
# 이름
# 길순  70  95  100  90  95
# 인아  70  95  100  90  95
# 서준  90  98   85  80  80

# %% [markdown]
# ### jeju1.csv 읽기

# %%
df = pd.read_csv("jeju1.csv", encoding="UTF8")
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   장소      11 non-null     str
#  1   LON     11 non-null     float64
#  2   LAT     11 non-null     float64
# dtypes: float64(2), str(1)
# memory usage: 396.0 bytes

# %%
df.head() # 처음 5개 행만 조회
# Out:
#        장소         LON        LAT
# 0  제주국제공항  126.496217  33.505314
# 1     돔베돈  126.526687  33.516084
# 2    공룡랜드  126.433153  33.442382
# 3  협재해수욕장  126.240463  33.404218
# 4    한림공원  126.239262  33.390101

# %%
df.tail(3) # 마지막 3개 행만 조회. 기본값:5
# Out:
#              장소         LON        LAT
# 8       저녁_오성식당  126.414549  33.256059
# 9        중문관광단지  126.412361  33.249186
# 10  숙소_서귀포KAL호텔  126.580954  33.248020

# %%
#LON 데이터만 출력하기
#print(df.LON)
print(df['LON'])
# Out:
# 0     126.496217
# 1     126.526687
# 2     126.433153
# 3     126.240463
# 4     126.239262
# 5     126.273744
# 6     126.289451
# 7     126.408691
# 8     126.414549
# 9     126.412361
# 10    126.580954
# Name: LON, dtype: float64

# %%
#LAT, LON 데이터 조회하기
df[["LAT","LON"]]
# Out:
#           LAT         LON
# 0   33.505314  126.496217
# 1   33.516084  126.526687
# 2   33.442382  126.433153
# 3   33.404218  126.240463
# 4   33.390101  126.239262
# 5   33.315127  126.273744
# 6   33.306537  126.289451
# 7   33.267972  126.408691
# 8   33.256059  126.414549
# 9   33.249186  126.412361
# 10  33.248020  126.580954

# %%
#장소를 인덱스로 변경하기
df.set_index("장소",inplace=True)
df
# Out:
#                     LON        LAT
# 장소
# 제주국제공항       126.496217  33.505314
# 돔베돈          126.526687  33.516084
# 공룡랜드         126.433153  33.442382
# 협재해수욕장       126.240463  33.404218
# 한림공원         126.239262  33.390101
# 유리의성         126.273744  33.315127
# 오설록티뮤지엄      126.289451  33.306537
# 테디베어뮤지엄      126.408691  33.267972
# 저녁_오성식당      126.414549  33.256059
# 중문관광단지       126.412361  33.249186
# 숙소_서귀포KAL호텔  126.580954  33.248020

# %%
#인덱스를 여행지 컬럼으로 생성하기
df["여행지"]=df.index
df
# Out:
#                     LON        LAT          여행지
# 장소
# 제주국제공항       126.496217  33.505314       제주국제공항
# 돔베돈          126.526687  33.516084          돔베돈
# 공룡랜드         126.433153  33.442382         공룡랜드
# 협재해수욕장       126.240463  33.404218       협재해수욕장
# 한림공원         126.239262  33.390101         한림공원
# 유리의성         126.273744  33.315127         유리의성
# 오설록티뮤지엄      126.289451  33.306537      오설록티뮤지엄
# 테디베어뮤지엄      126.408691  33.267972      테디베어뮤지엄
# 저녁_오성식당      126.414549  33.256059      저녁_오성식당
# 중문관광단지       126.412361  33.249186       중문관광단지
# 숙소_서귀포KAL호텔  126.580954  33.248020  숙소_서귀포KAL호텔

# %%
#reset_index : 인덱스를 일반컬럼으로 변경하기. 인덱스는 range형식으로 설정됨
df.reset_index(inplace=True)
df
# Out:
#              장소         LON        LAT          여행지
# 0        제주국제공항  126.496217  33.505314       제주국제공항
# 1           돔베돈  126.526687  33.516084          돔베돈
# 2          공룡랜드  126.433153  33.442382         공룡랜드
# 3        협재해수욕장  126.240463  33.404218       협재해수욕장
# 4          한림공원  126.239262  33.390101         한림공원
# 5          유리의성  126.273744  33.315127         유리의성
# 6       오설록티뮤지엄  126.289451  33.306537      오설록티뮤지엄
# 7       테디베어뮤지엄  126.408691  33.267972      테디베어뮤지엄
# 8       저녁_오성식당  126.414549  33.256059      저녁_오성식당
# 9        중문관광단지  126.412361  33.249186       중문관광단지
# 10  숙소_서귀포KAL호텔  126.580954  33.248020  숙소_서귀포KAL호텔

# %%
#장소 컬럼을 제거하기
#df.drop("장소", inplace=True, axis=1)
#del df["장소"]

# %%
df
# Out:
#            LON        LAT          여행지
# 0   126.496217  33.505314       제주국제공항
# 1   126.526687  33.516084          돔베돈
# 2   126.433153  33.442382         공룡랜드
# 3   126.240463  33.404218       협재해수욕장
# 4   126.239262  33.390101         한림공원
# 5   126.273744  33.315127         유리의성
# 6   126.289451  33.306537      오설록티뮤지엄
# 7   126.408691  33.267972      테디베어뮤지엄
# 8   126.414549  33.256059      저녁_오성식당
# 9   126.412361  33.249186       중문관광단지
# 10  126.580954  33.248020  숙소_서귀포KAL호텔

# %%
# to_csv : df 데이터를 csv파일로 생성하기
df.to_csv("df_jeju.csv",index=False) #index=False : 인덱스는 파일에서 제외

# %%
dict_data = {'c0':[1,2,3], 'c1':[4,5,6], 'c2':[7,8,9], \
             'c3':[10,11,12], 'c4':[13,14,15]}
df = pd.DataFrame(dict_data, index=['r0', 'r1', 'r2'])
print(df)
# Out:
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15

# %%
#reindex : 인덱스 재지정. 행의 수가 3개인데, 인덱스를 5개로 설정하기
ndf = df.reindex(['r0', 'r1', 'r2','r3','r4'])
ndf.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 5 entries, r0 to r4
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   c0      3 non-null      float64
#  1   c1      3 non-null      float64
#  2   c2      3 non-null      float64
#  3   c3      3 non-null      float64
#  4   c4      3 non-null      float64
# dtypes: float64(5)
# memory usage: 240.0+ bytes

# %%
#reindex : 인덱스 재지정. 행의 수가 3개인데, 인덱스를 5개로 설정하기. 결측값을 0으로 채우기
ndf2 = df.reindex(['r0', 'r1', 'r2','r3','r4'],fill_value=0)
ndf2
# Out:
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15
# r3   0   0   0   0   0
# r4   0   0   0   0   0

# %%
# ndf2데이터의 인덱스를 컬럼으로 변경하기
ndf3 = ndf2.reset_index()
ndf3
# Out:
#   index  c0  c1  c2  c3  c4
# 0    r0   1   4   7  10  13
# 1    r1   2   5   8  11  14
# 2    r2   3   6   9  12  15
# 3    r3   0   0   0   0   0
# 4    r4   0   0   0   0   0

# %%
# 정렬하기
# sort_index  : 인덱스 데이터기준으로 정렬
# sort_values : 지정된 컬럼을 기준으로 정렬
# df데이터를 인덱스의 내림차순으로 정렬하기
ndf = df.sort_index(ascending=False)
#ndf
# ndf데이터를 인덱스의 오름차순으로 정렬하기
ndf = ndf.sort_index(ascending=True) #기본값
ndf
# Out:
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15

# %%
# c1 컬럼 기준 내림차순 정렬하기
ndf = df.sort_values(by='c1', ascending=False)
ndf
# Out:
#     c0  c1  c2  c3  c4
# r2   3   6   9  12  15
# r1   2   5   8  11  14
# r0   1   4   7  10  13

# %%
df = pd.DataFrame(exam_data)
df
# Out:
#    이름  수학  영어   음악   체육
# 0  서준  90  98   85  100
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90

# %%
#이름의 역순으로 정렬하여 출력하기
df_name = df.sort_values(by="이름",ascending=False)
df_name
# Out:
#    이름  수학  영어   음악   체육
# 2  인아  70  95  100   90
# 1  우현  80  89   95   90
# 0  서준  90  98   85  100

# %%
#영어 점수 순으로 정렬하여 출력하기
df_math = df.sort_values(by="영어")
df_math
# Out:
#    이름  수학  영어   음악   체육
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90
# 0  서준  90  98   85  100

# %% [markdown]
# ### titanic 데이터 실습

# %%
# !pip3 install seaborn

# %%
import pandas as pd
import seaborn as sns #pip3 install seaborn
# seaborn 모듈에 등록된 데이터셋 목록
print(sns.get_dataset_names())
# Out:
# Matplotlib is building the font cache; this may take a moment.
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
#titanic 데이터 로드
titanic = sns.load_dataset("titanic")
titanic.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    str
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    str
#  8   class        891 non-null    category
#  9   who          891 non-null    str
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    str
#  13  alive        891 non-null    str
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), str(5)
# memory usage: 80.7 KB

# %%
titanic.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  22.0      1      0  7.25        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False

# %%
# 컬럼명 조회하기
titanic.columns
''' 
survived 생존여부
pclass 좌석등급 (숫자)
sex 성별 (male, female)
age 나이
sibsp 형제자매 + 배우자 인원수
parch: 부모 + 자식 인원수
fare: 요금
embarked 탑승 항구
class 좌석등급 (영문)
who 성별 (man, woman)
adult_male 성인남자여부
deck 선실 고유 번호 가장 앞자리 알파벳
embark_town 탑승 항구 (영문)
alive 생존여부 (영문)
alone 혼자인지 여부
'''
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='str')

# %%
#titanic 의 age, fare 컬럼만 df 데이터셋에 저장하기
#df = titanic[["age","fare"]]
#df.head()
df = titanic.loc[:,["age","fare"]]
df.head()

# %%
#df 데이터에 10 더하기
addtion = df+10
addtion.head()
# Out:
#     age     fare
# 0  32.0  17.2500
# 1  48.0  81.2833
# 2  36.0  17.9250
# 3  45.0  63.1000
# 4  45.0  18.0500

# %%
#데이터프레임 - 데이터프레임
sub = addtion - df
sub.head()
# Out:
#     age  fare
# 0  10.0  10.0
# 1  10.0  10.0
# 2  10.0  10.0
# 3  10.0  10.0
# 4  10.0  10.0

# %%
# addition 데이터를 이용하여 df데이터와 같은 df2 데이터생성하기
df2 = addtion - 10
df.head()
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
# auto-mgp.csv 파일을 읽어서  df 데이터프레임 데이터로 생성하기
df = pd.read_csv("auto-mpg.csv",header=None)

#컬럼명 지정하기
df.columns = ['mpg','cylinders','displacement',
              'horsepower','weight','acceleration',
              'model year','origin','name']
df.head()
'''
mpg   :  연비
cylinders : 실린더 수
displacement : 배기량
horsepower : 출력
weight : 차량무게
acceleration : 가속능력
model year : 출시년도
origin : 제조국
name : 모델명
'''
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    str
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    str
# dtypes: float64(4), int64(3), str(2)
# memory usage: 28.1 KB

# %%
#df 데이터의 행,열의 갯수 조회하기
df.shape #(398행, 9열)
# Out:
# (398, 9)

# %%
df.dtypes # 컬럼의 자료형
#mpg 컬럼의 자료형 출력하기
print(df.mpg.dtypes)
# Out:
# float64

# %%
# describe : 통계 정보 조회하기
#df.describe() #자료형이 숫자형인 경우만 출력
df.describe(include="all")
# Out:
#                mpg   cylinders  displacement horsepower       weight  \
# count   398.000000  398.000000    398.000000        398   398.000000
# unique         NaN         NaN           NaN         94          NaN
# top            NaN         NaN           NaN      150.0          NaN
# freq           NaN         NaN           NaN         22          NaN
# mean     23.514573    5.454774    193.425879        NaN  2970.424623
# std       7.815984    1.701004    104.269838        NaN   846.841774
# min       9.000000    3.000000     68.000000        NaN  1613.000000
# 25%      17.500000    4.000000    104.250000        NaN  2223.750000
# 50%      23.000000    4.000000    148.500000        NaN  2803.500000
# 75%      29.000000    8.000000    262.000000        NaN  3608.000000
# max      46.600000    8.000000    455.000000        NaN  5140.000000
#
#         acceleration  model year      origin        name
# count     398.000000  398.000000  398.000000         398
# ...

# %%
#df 레코드 갯수 (결측값 제외) 조회하기.
df.count()
#mpg 컬럼의 레코드 갯수(결측값 제외) 조회하기
df.mpg.count()
#df 평균 조회하기
#df 의 mpg컬럼의 평균 조회하기
print(df[["mpg","weight"]].mean()) #숫자형식의 데이터만 가능
print(df.mpg.mean())
print(df['mpg'].mean())
#중간값 : median()
#표준편차 : std()
#분산 : var()
#최대값 : max()
#최소값 : min()
#상관계수 : corr()
print(df.mpg.var())

print(df[["mpg","weight"]].corr())
# Out:
# mpg         23.514573
# weight    2970.424623
# dtype: float64
# 23.514572864321607
# 23.514572864321607
# 61.089610774274405
#              mpg    weight
# mpg     1.000000 -0.831741
# weight -0.831741  1.000000

# %%
#특정 컬럼의 값의 갯수
df["cylinders"].value_counts() #갯수가 많은 순으로 출력됨
# Out:
# cylinders
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: count, dtype: int64

# %%
#origin 컬럼의 값별로 갯수 출력하기
print(df["origin"].value_counts())
print(df.origin.value_counts())
# Out:
# origin
# 1    249
# 3     79
# 2     70
# Name: count, dtype: int64
# origin
# 1    249
# 3     79
# 2     70
# Name: count, dtype: int64

# %%
value_cnt = df["origin"].value_counts()
print(type(value_cnt))
# Out:
# <class 'pandas.Series'>

# %% [markdown]
# ### json 데이터를 이용하여 DataFrame 객체 생성하기

# %%
import json
price = {
    'date' : '2026-09-16',
    'price' : {
        'Apple':800,
        'Orange' : 1000,
        'Banana' : 500
    }
}
print(type(price))
#json 형식의 파일로 저장하기
result = pd.DataFrame(price)
result
#json 형식의 파일로 저장하기
json.dump(price,open("price.json","w"))
# Out:
# <class 'dict'>

# %%
# json 파일을 읽어서 DataFrame으로 생성하기
df = pd.read_json('price.json')
df
# Out:
#              date  price
# Apple  2026-09-16    800
# Orange 2026-09-16   1000
# Banana 2026-09-16    500

# %% [markdown]
# ### excel 파일을 읽어 DataFrame 데이터로 생성하기

# %%
# !python3.12 -m pip install --upgrade pip

# %%
# !pip3 install openpyxl    #xlsx 파일만 읽기 가능.

# %%
#남북한발전전력량.xlsx 파일을 읽어서 df 변수에 저장하기
df = pd.read_excel("남북한발전전력량.xlsx")
df
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   236
# 6       NaN     수력   156   150   142   133   138   142   125   107  ...   133
# 7       NaN     화력   121   113   105    88    93    88    88    86  ...   103
# 8       NaN    원자력     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 29 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   전력량 (억㎾h)  2 non-null      str
#  1   발전 전력별     9 non-null      str
#  2   1990       9 non-null      object
#  3   1991       9 non-null      object
#  4   1992       9 non-null      object
#  5   1993       9 non-null      object
#  6   1994       9 non-null      object
#  7   1995       9 non-null      object
#  8   1996       9 non-null      object
#  9   1997       9 non-null      object
#  10  1998       9 non-null      object
#  11  1999       9 non-null      object
#  12  2000       9 non-null      object
#  13  2001       9 non-null      object
#  14  2002       9 non-null      object
#  15  2003       9 non-null      object
#  16  2004       9 non-null      object
#  17  2005       9 non-null      object
#  18  2006       9 non-null      object
#  19  2007       9 non-null      object
# ...

# %%
# 남한,북한의 합계전력량만 ndf변수 저장하기
#ndf = df.iloc[[0,5],2:]
ndf = df.loc[[0,5],"1990":]
ndf
# Out:
#    1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  ...  2007  \
# 0  1077  1186  1310  1444  1650  1847  2055  2244  2153  2393  ...  4031
# 5   277   263   247   221   231   230   213   193   170   186  ...   236
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 5   255   235   237   211   215   221   216   190   239
#
# [2 rows x 27 columns]

# %%
# ndf의 인덱스값을 South,North으로 설정하기
ndf.index=['South','North']
#ndf.info()
ndf.columns
# Out:
# Index(['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016'],
#       dtype='str')

# %%
#컬럼명의 자료형을 정수형으로 변경하기
ndf.columns = ndf.columns.map(int)
ndf.columns
# Out:
# Index([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#        2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
#        2014, 2015, 2016],
#       dtype='int64')

# %%
#plot() ; 선그래프로 출력하기
ndf.plot()
# Out:
# <Axes: >

# %%
#행열 치환하기 : 전치행렬
ndf.shape
ndf2 = ndf.T #전치행렬
ndf2.shape
ndf2.head()

# %%
ndf2.plot() #선그래프
# Out:
# <Axes: >

# %%
ndf2.South
# Out:
# 1990    1077
# 1991    1186
# 1992    1310
# 1993    1444
# 1994    1650
# 1995    1847
# 1996    2055
# 1997    2244
# 1998    2153
# 1999    2393
# 2000    2664
# 2001    2852
# 2002    3065
# 2003    3225
# 2004    3421
# 2005    3646
# 2006    3812
# 2007    4031
# 2008    4224
# 2009    4336
# 2010    4747
# 2011    4969
# 2012    5096
# 2013    5171
# 2014    5220
# 2015    5281
# 2016    5404
# Name: South, dtype: object

# %%
#남한 전력량 히스토그램 그래프
#히스토그램 : 데이터 범위별 갯수 막대그래프로 표현함. 데이터의 분포를 판단할 수 있는 그래프
ndf2.South.plot(kind="hist")
ndf2.plot(kind="hist",y='South')
# Out:
# <Axes: ylabel='Frequency'>

# %%
ndf2.North.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# 산점도 그래프 
ndf2.plot(x='South',y="North",kind="scatter")

# %%
#auto-mpg.csv 파일을 읽어서  mpg 컬럼과 weight컬럼의 산점도 그래프를 출력하기
#mpg 컬럼과 weight컬럼의 상관계수를 출력하기
df = pd.read_csv("auto-mpg.csv",header=None)

#컬럼명 지정하기
df.columns = ['mpg','cylinders','displacement',
              'horsepower','weight','acceleration',
              'model year','origin','name']

# %%
df.plot(x='mpg',y='weight',kind='scatter')
# Out:
# <Axes: xlabel='mpg', ylabel='weight'>

# %%
df[["mpg","weight"]].corr()
# Out:
#              mpg    weight
# mpg     1.000000 -0.831741
# weight -0.831741  1.000000

# %%
df[["mpg","cylinders"]].corr()
# Out:
#                 mpg  cylinders
# mpg        1.000000  -0.775396
# cylinders -0.775396   1.000000

# %%
df.plot(x='mpg',y='cylinders',kind='scatter')
# Out:
# <Axes: xlabel='mpg', ylabel='cylinders'>

# %%
#box 그래프
df[['mpg','cylinders']].plot(kind='box')
# Out:
# <Axes: >

# %%
#mpg 데이터의 히스토그램 그래프 
#df["mpg"].plot(kind='hist')
df[["mpg"]].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df = pd.read_excel("시도별 전출입 인구수.xlsx")
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 50 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   전출지별    19 non-null     str
#  1   전입지별    325 non-null    str
#  2   1970    325 non-null    object
#  3   1971    325 non-null    object
#  4   1972    325 non-null    object
#  5   1973    325 non-null    object
#  6   1974    325 non-null    object
#  7   1975    325 non-null    object
#  8   1976    325 non-null    object
#  9   1977    325 non-null    object
#  10  1978    325 non-null    object
#  11  1979    325 non-null    object
#  12  1980    325 non-null    object
#  13  1981    325 non-null    object
#  14  1982    325 non-null    object
#  15  1983    325 non-null    object
#  16  1984    325 non-null    object
#  17  1985    325 non-null    object
#  18  1986    325 non-null    object
#  19  1987    325 non-null    object
#  20  1988    325 non-null    object
# ...

# %%
df.head()
# Out:
#    전출지별   전입지별      1970      1971      1972      1973      1974      1975  \
# 0  전출지별   전입지별  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1    전국     전국   4046536   4210164   3687938   4860418   5297969   9011440
# 2   NaN  서울특별시   1742813   1671705   1349333   1831858   2050392   3396662
# 3   NaN  부산광역시    448577    389797    362202    482061    680984    805979
# 4   NaN  대구광역시         -         -         -         -         -         -
#
#        1976      1977  ...      2008      2009      2010      2011      2012  \
# 0  이동자수 (명)  이동자수 (명)  ...  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1   6773250   7397623  ...   8808256   8487275   8226594   8127195   7506691
# 2   2756510   2893403  ...   2025358   1873188   1733015   1721748   1555281
# 3    724664    785117  ...    514502    519310    519334    508043    461042
# 4         -         -  ...    409938    398626    370817    370563    348642
#
#        2013      2014      2015      2016      2017
# ...

# %%
# ffill : 결측값을 앞데이터로 채우기. fillna(method='ffill') 함수가 변경됨
# bfill : 결측값을 뒤데이터로 채우기. fillna(method='bfill') 함수가 변경됨
df = df.ffill()
df.info()
df.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 50 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   전출지별    325 non-null    str
#  1   전입지별    325 non-null    str
#  2   1970    325 non-null    object
#  3   1971    325 non-null    object
#  4   1972    325 non-null    object
#  5   1973    325 non-null    object
#  6   1974    325 non-null    object
#  7   1975    325 non-null    object
#  8   1976    325 non-null    object
#  9   1977    325 non-null    object
#  10  1978    325 non-null    object
#  11  1979    325 non-null    object
#  12  1980    325 non-null    object
#  13  1981    325 non-null    object
#  14  1982    325 non-null    object
#  15  1983    325 non-null    object
#  16  1984    325 non-null    object
#  17  1985    325 non-null    object
#  18  1986    325 non-null    object
#  19  1987    325 non-null    object
#  20  1988    325 non-null    object
# ...

# %%
#전출지가 서울에서 다른 지역으로 이동한 데이터만 추출하기
#전출지 서울이고, 전입지가 서울이 아닌 데이터만 추출하기
mask = (df["전출지별"] == '서울특별시') & (df["전입지별"] != '서울특별시')
print(mask.head())
print(mask.value_counts())
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
# False    308
# True      17
# Name: count, dtype: int64

# %%
df_seoul = df[mask] #mask의 값이 True인 데이터만 리턴
df_seoul.shape
# Out:
# (17, 50)

# %%
#컬럼명이 전입지별=>전입지 설정하기. 컬럼명 변경하기
print(df_seoul.columns)
df_seoul.rename(columns={"전입지별":"전입지"},inplace=True)
print(df_seoul.columns)
# Out:
# Index(['전출지별', '전입지별', '1970', '1971', '1972', '1973', '1974', '1975', '1976',
#        '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017'],
#       dtype='str')
# Index(['전출지별', '전입지', '1970', '1971', '1972', '1973', '1974', '1975', '1976',
#        '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017'],
#       dtype='str')

# %%
#전입지 컬럼을 인덱스 설정하기
df_seoul.set_index('전입지',inplace=True)
df_seoul

# %%
#전출지별 컬럼 제거하기
del df_seoul["전출지별"]
df_seoul

# %%
# sr1 변수에 경기도로 이전한 데이터만 저장하기
sr1 = df_seoul.loc['경기도']
sr1  #서울에서 경기도로 이전한 데이터

# %% [markdown]
# # matplotlib 모듈로 시각화 하기

# %%
import matplotlib.pyplot as plt
#기본폰트가 한글폰트를 제공하지 않음. 한글 사용을 위해 한글가능한 폰트로 설정해야함
# 윈도우 : Malgun Gothic
# 맥 : AppleGothic
plt.rc('font',family='AppleGothic')

# %%
#plt.plot(sr1.index,sr1.values). #sr1.index : x축, sr1.values : y축
plt.plot(sr1)
plt.title("서울=>경기 인구 이동")
plt.xlabel("년도")
plt.ylabel("이동인구수")
# Out:
# Text(0, 0.5, '이동인구수')

# %%
plt.figure(figsize=(14,5))      #가로:14, 세로:5
plt.xticks(rotation='vertical') #x축의 라벨을 세로로 출력
plt.plot(sr1)
plt.title("서울=>경기 인구 이동")
plt.xlabel("년도")
plt.ylabel("이동인구수")
plt.legend(labels=['서울->경기'],loc='best') #범례 표시. 위치는 적당한곳

# %%
#스타일 정보
plt.style.available
# Out:
# ['Solarize_Light2',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'petroff6',
#  'petroff8',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# 그래프의 스타일 지정하기
plt.style.use("ggplot")
plt.figure(figsize=(14,5))      #가로:14, 세로:5
plt.xticks(rotation='vertical',size=8) #x축의 라벨을 세로로 출력
plt.plot(sr1, marker='o',markersize=7)
plt.title("서울=>경기 인구 이동")
plt.xlabel("년도")
plt.ylabel("이동인구수")
plt.ylim(0,800000) #y축의 범위 지정
# annotate : 그래프에 주석 표시하기
plt.annotate('',
      xy=(20, 620000),       #화살표의 머리 부분(끝점)
      xytext=(2, 290000),    #화살표의 꼬리 부분(시작점)
      xycoords='data',       #좌표체계
      arrowprops=dict(arrowstyle='->', color='skyblue', lw=5), #화살표 서식
)
plt.annotate('',
     xy=(47, 450000),       #화살표의 머리 부분(끝점)
     xytext=(30, 580000),   #화살표의 꼬리 부분(시작점)
     xycoords='data',       #좌표체계
    arrowprops=dict(arrowstyle='->', color='olive', lw=5),  #화살표 서식
 )
# 주석 표시 - 글자 설정.
plt.annotate('인구이동 증가(1970-1995)', #텍스트 입력
             xy=(10, 450000),           #텍스트 위치 기준점
             rotation=22,               #텍스트 회전각도
             va='baseline',             #텍스트 상하 정렬
             ha='center',               #텍스트 좌우 정렬
             fontsize=15,               #텍스트 크기
             )
plt.annotate('인구이동 감소(1995-2017)',  #텍스트 입력
             xy=(40, 560000),            #텍스트 위치 기준점
             rotation=-11,               #텍스트 회전각도
             va='baseline',              #텍스트 상하 정렬
             ha='center',                #텍스트 좌우 정렬
             fontsize=15,                #텍스트 크기
             )
# Out:
# Text(40, 560000, '인구이동 감소(1995-2017)')

# %%
# 2 개의 그래프를 출력하기
fig = plt.figure(figsize=(10,10))
ax1 =fig.add_subplot(2,1,1) # 2행1열로 분리. 1번째 공간
ax2 =fig.add_subplot(2,1,2) # 2행1열로 분리. 2번째 공간
ax1.plot(sr1,'o',markersize=7)
ax2.plot(sr1,marker='o',markersize=7,
         markerfacecolor='green',color='olive',linewidth=2,label='서울->경기')
#y축의 범위 지정
ax1.set_ylim(1000,700000)
ax2.set_ylim(1000,700000)
#sr1.index 값으로 x축 레이블 출력을 75도정도 회전
ax1.set_xticklabels(sr1.index,rotation=75)
ax2.set_xticklabels(sr1.index,rotation=75)
# Out:
# /var/folders/mh/0t1hl02s4qj6dv8cr62bzbw00000gn/T/ipykernel_1264/3165191005.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator. Otherwise, ticks may be mislabeled.
#   ax1.set_xticklabels(sr1.index,rotation=75)
# /var/folders/mh/0t1hl02s4qj6dv8cr62bzbw00000gn/T/ipykernel_1264/3165191005.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator. Otherwise, ticks may be mislabeled.
#   ax2.set_xticklabels(sr1.index,rotation=75)
# [Text(0, 0, '1970'),
#  Text(1, 0, '1971'),
#  Text(2, 0, '1972'),
#  Text(3, 0, '1973'),
#  Text(4, 0, '1974'),
#  Text(5, 0, '1975'),
#  Text(6, 0, '1976'),
#  Text(7, 0, '1977'),
#  Text(8, 0, '1978'),
#  Text(9, 0, '1979'),
#  Text(10, 0, '1980'),
#  Text(11, 0, '1981'),
#  Text(12, 0, '1982'),
#  Text(13, 0, '1983'),
#  Text(14, 0, '1984'),
#  Text(15, 0, '1985'),
#  Text(16, 0, '1986'),
# ...

# %%
# 서울에서 충청남도, 경상북도, 강원도 이동한 인구 데이터를 sr2 데이터에 저장하기
# 1970년대 데이터 조회하기
col_year = list(map(str,range(1970,1980)))
col_year
sr2 = df_seoul.loc[['충청남도','경상북도','강원도'],col_year]
sr2
# Out:
#        1970   1971   1972   1973   1974   1975   1976   1977   1978   1979
# 전입지
# 충청남도  15954  18943  23406  27139  25509  51205  41447  43993  48091  45388
# 경상북도  11868  16459  22073  27531  26902  46177  40376  41155  42940  43565
# 강원도    9352  12885  13561  16481  15479  27837  25927  25415  26700  27599

# %%
fig = plt.figure(figsize=(20,5))
ax = fig.add_subplot(1,1,1)
#col_year : x축라벨값
#sr2.loc['충청남도',:] : y축 데이터
ax.plot(col_year,sr2.loc['충청남도',:],marker='o',markerfacecolor='green',
        markersize=10,color='olive',linewidth=2,label='서울->충남')
ax.plot(col_year,sr2.loc['경상북도',:],marker='o',markerfacecolor='blue',
        markersize=10,color='skyblue',linewidth=2,label='서울->경북')
ax.plot(col_year,sr2.loc['강원도',:],marker='o',markerfacecolor='red',
        markersize=10,color='magenta',linewidth=2,label='서울->강원')
ax.legend(loc="best")  #범례 표시. 최적위치에
ax.set_title('서울->충남,경북,강원 인구이동',size=20)
ax.set_xlabel('기간',size=12)
ax.set_ylabel('인구이동수',size=12)
ax.set_xticks(range(len(col_year)))
ax.set_xticklabels(col_year,rotation=90)
ax.set_xticklabels(col_year)
ax.tick_params(axis='x',labelsize=10)
ax.tick_params(axis='y',labelsize=10)
